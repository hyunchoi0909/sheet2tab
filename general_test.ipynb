# %%
from sheet2tab import preprocess
from sheet2tab.environment import *
import pandas as pd
import time
import tqdm
import os
import re
import random

# %%
import guitarpro as gp

# %%
os.chdir(pathenv.DATA_RAW)
files = os.listdir()
random.shuffle(files)

# %%
start = time.time()
for i in range(100):
    file = files[i]
    print(file)
    tracks = preprocess.process(file)
    track_num = 0
    for track in tracks:
        track.to_csv("..\\temp\\{}{}.csv".format(file.rsplit(',')[0], "-[{}]".format(track_num)))
        track_num += 1
end = time.time()
# Out:
# montgomery,wes-unit7.gp4
# rancid-blackhawkdown.gp4
# slipknot-circle.gp4
# aliceinchains-rooster(acoustic).gp3
# beatles(the)-freeasabird.gp4
# kumlehn,jürgen-thesuninthewest.gp4
# hefner-thesadwitch.gp4
# direstraits-tunneloflove.gp3
# gerge-thesilenceofthenight.gp4
# saosin-lostsymphonies.gp4
# dragojevic,oliver-cesarica.gp3
# boudbadx-beautifulworldlivin_'in.gp3
# killers,serial-semsensura.gp3
# guccini,francesco-autogrill.gp4
# cranberries-iwillalways.gp3
# doctorcaspersrabbitshow-echlomlanetsachintro.gp3
# unknown-jumpinjackflash.gp3
# mokoma-vaderetro,satana!.gp3
# grinspoon-badfunkstripe(intro).gp3
# systemofadown-nuguns.gp3
# placebo-sleepingwithghosts.gp4
# machinehead-blistering.gp4
# Error with machinehead-blistering.gp4
# No objects to concatenate
# pinkfloyd-keeptalking.gp3
# lofofora-weedo.gp4
# tesla-trysohard.gp3
# composersofmsb-ashortstory.gp4
# dosminutos-barricadapolicial.gp4
# doorframe-foreverandaday.gp3
# nevrosis-banefulpenumbra.gp4
# clapton,eric-beforeyouaccuseme.gp4
# extremoduro-abrazadoalatristeza.gp3
# anti-lag-flagstars&stripes.gp3
# dogma-diesel.gp4
# ancientrites-victoryorvalhalla(lastmanstanding).gp4
# refuellingbase-doomii-e1m1hangar.gp4
# rocklicks-powerchordpickingexercises.gp3
# whitestripes-wastingmytime.gp4
# sads-hello.gp4
# painofsalvation-nihilmorari.gp4
# lynyrdskynyrd-freebird(live).gp4
# dropkickmurphys-amazinggrace.gp4
# almafuerte-tueressuseguridad.gp4
# marsvolta(the)-roulettedares.gp4
# paganini,nicolo-motoperorio.gp3
# callusjunior'sproject-fearofthedark.gp3
# rainbow-rainboweyes.gp3
# Error with rainbow-rainboweyes.gp3
# No objects to concatenate
# slippy-metamorphosis.gp4
# norther-hellhole.gp4
# Error with norther-hellhole.gp4
# No objects to concatenate
# haydn,joseph-allegretofromsymphonyno100ing.gp4
# artofyngwiemalmsteen-openingsolo.gp4
# kiss-iwantitloud.gp4
# judge,mike-beavisandbuttheadtheme.gp3
# nepallica-mayaraprem.gp4
# sor,fernando-andante.gp4
# strangeland-seasonsofdeath.gp4
# nirvana-polly.gp3
# placebo-commercialforlevi.gp4
# sanz,gaspar-rujero(from5dances).gp3
# rossi,vasco-buoniocattivi.gp4
# rammstein-wobistdu.gp4
# beatles-backintheussr.gp3
# reed,lou-perfectday.gp3
# nofx-herojuana.gp3
# dieärzte-duwillstmichküssen.gp3
# profiction-tribute.gp4
# ironfire-journeyman.gp4
# satum'spals-nightmares.gp3
# ulver-hoyfjeldsbilde.gp4
# advisory-youcandoit.gp3
# budkasuflera-strefapolcienia.gp3
# nineinchnails-becoming.gp3
# inflexibleresistance-forgettingyourname.gp4
# thrice-asubtledagger.gp4
# anco-journeythroughthevalley(tothekingdomoflight).gp4
# rastenburg-capilare.gp3
# masshysteria-finistőreamer.gp3
# therion-seawinds.gp3
# tété-unebonnepairedeclaques.gp3
# dreamtheater-achangeofseasons.gp4
# goldman,jeanjacques-jacqueslapluie.gp3
# manowar-returnofthewarlord.gp4
# nilsson-everybody_'stalkin_'.gp4
# rammstein-adios.gp4
# lacrimasprofundere-enchantedandinsilentbeauty.gp4
# panda-yanoessuficientelamentar.gp4
# ksu-jaboloweofiary.gp4
# lockx-blockxfly.gp3
# velvetunderground-femmefatale.gp3
# blindside-eyeofthestorm.gp4
# cure-inbetweendays.gp3
# dreamtheater-blindfaith.gp3
# symphonyx-evolution(thegranddesign).gp4
# 311-lightyears.gp3
# terwilliger,andrew-diesel.gp3
# reinhardt,django-areyouinthemood.gp3
# notavailable-jo'anna.gp4
# alternativecompetition5-macumba'sgroove.gp4
# ratablanca-ratablancapreludioobsesivo.gp3
# estigia-lagrimasdelmal.gp4
# asiankungfugeneration-kaigandoori.gp4

# %%
print((end-start)/100)
# Out:
# 0.5052214860916138

# %%
st = time.time()
os.chdir(pathenv.DATA_RAW)
files = os.listdir()

for file in tqdm.tqdm(files):
    try:
        song = gp.parse(file)
        for track in song.tracks:
            check = False
            if not det_guitar(track): continue
            for measure in track.measures:
                if len(measure.voices) > 2:
                    print(file)
                    print(track.name)
                    print(len(measure.voices))
                    check = True
                    break
            if check: break
    except Exception as e:
        print("failure with {}".format(file))
        print(e)
# Out:
#   1%|▋                                                                           | 417/42279 [01:29<2:03:26,  5.65it/s]
# failure with acdc-biggun.gp3
# unsupported version 'FICHIER GUITARE PRO v1.04'
#   2%|█▌                                                                          | 877/42279 [03:23<1:29:32,  7.71it/s]
# failure with alanjackson-holeinthewall(intro).gp3
# unpack requires a buffer of 1 bytes
#   3%|██                                                                         | 1144/42279 [04:21<2:36:54,  4.37it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 7
#       5 for file in tqdm.tqdm(files):
#       6     try:
# ----> 7         song = gp.parse(file)
#       8         for track in song.tracks:
#       9             check = False
#
# File ~\anaconda3\envs\datascience\lib\site-packages\guitarpro\io.py:60, in parse(stream, encoding)
#      58 gpfile, shouldClose = _open(None, stream, 'rb', encoding=encoding)
#      59 try:
# ---> 60     return gpfile.readSong()
#      61 finally:
#      62     if shouldClose:
#
# File ~\anaconda3\envs\datascience\lib\site-packages\guitarpro\gp3.py:59, in GP3File.readSong(self)
#      57     self.readMeasureHeaders(song, measureCount)
#      58     self.readTracks(song, trackCount, channels)
# ---> 59     self.readMeasures(song)
#      60 return song
#
# File ~\anaconda3\envs\datascience\lib\site-packages\guitarpro\gp3.py:391, in GP3File.readMeasures(self, song)
#     389         self._currentMeasureNumber = measure.number
#     390         track.measures.append(measure)
# --> 391         self.readMeasure(measure)
#     392     start += header.length
#     394 self._currentTrack = None
#
# File ~\anaconda3\envs\datascience\lib\site-packages\guitarpro\gp3.py:406, in GP3File.readMeasure(self, measure)
#     404 voice = measure.voices[0]
#     405 self._currentVoiceNumber = 1
# --> 406 self.readVoice(start, voice)
#     407 self._currentVoiceNumber = None
#
# File ~\anaconda3\envs\datascience\lib\site-packages\guitarpro\gp3.py:413, in GP3File.readVoice(self, start, voice)
#     411 for beat in range(beats):
#     412     self._currentBeatNumber = beat + 1
# --> 413     start += self.readBeat(start, voice)
#     414 self._currentBeatNumber = None
#
# File ~\anaconda3\envs\datascience\lib\site-packages\guitarpro\gp3.py:453, in GP3File.readBeat(self, start, voice)
#     451 else:
#     452     beat.status = gp.BeatStatus.normal
# --> 453 duration = self.readDuration(flags)
#     454 noteEffect = gp.NoteEffect()
#     455 if flags & 0x02:
#
# File ~\anaconda3\envs\datascience\lib\site-packages\guitarpro\gp3.py:497, in GP3File.readDuration(self, flags)
#     480 """Read beat duration.
#     481
#     482 Duration is composed of byte signifying duration and an integer
#    (...)
#     494 If flag at *0x20* is true, the tuplet is read.
#     495 """
#     496 duration = gp.Duration()
# --> 497 duration.value = 1 << (self.readSignedByte() + 2)
#     498 duration.isDotted = bool(flags & 0x01)
#     499 if flags & 0x20:
#
# File ~\anaconda3\envs\datascience\lib\site-packages\guitarpro\iobase.py:65, in GPFileBase.readSignedByte(self, count, default)
#      63 """Read 1 signed byte *count* times."""
#      64 args = ('b', 1)
# ---> 65 return (self.read(*args, default=default) if count == 1 else
#      66         [self.read(*args, default=default) for i in range(count)])
#
# File ~\anaconda3\envs\datascience\lib\site-packages\guitarpro\iobase.py:47, in GPFileBase.read(self, fmt, count, default)
#      45 def read(self, fmt, count, default=None):
#      46     try:
# ---> 47         data = self.data.read(count)
#      48         result = struct.unpack(fmt, data)
#      49         return result[0]
#
# KeyboardInterrupt:

# %%
'''test = subprocess.run(["dir"], capture_output=True, text=True)
print(test)
test2 = subprocess.run([environment.pathenv.MUSESCORE, "--help"], capture_output=True, text=True)
print(test2)
preprocess.XMLconvert(".\metal.gp4", ".\textjupyter2.xml")
# Out:
#   Cell In[1], line 1
#     '''test = subprocess.run(["dir"], capture_output=True, text=True)
#     ^
# SyntaxError: incomplete input

# %%
import guitarpro

file = '.\\rawdata\\Metallica - Enter Sandman (6).gp3'
song = guitarpro.parse(file)
print(song)

# %%
for track in song.tracks:
    print(track.name)
    print(track.number)
    print(track.strings)
vocals = song.tracks[1]
print(vocals.strings[0].value)
# Out:
# Vocals
# 1
# [GuitarString(number=1, value=64), GuitarString(number=2, value=59), GuitarString(number=3, value=55), GuitarString(number=4, value=50), GuitarString(number=5, value=45), GuitarString(number=6, value=40)]
# James
# 2
# [GuitarString(number=1, value=64), GuitarString(number=2, value=59), GuitarString(number=3, value=55), GuitarString(number=4, value=50), GuitarString(number=5, value=45), GuitarString(number=6, value=40)]
# Kirk
# 3
# [GuitarString(number=1, value=64), GuitarString(number=2, value=59), GuitarString(number=3, value=55), GuitarString(number=4, value=50), GuitarString(number=5, value=45), GuitarString(number=6, value=40)]
# Jason
# 4
# [GuitarString(number=1, value=43), GuitarString(number=2, value=38), GuitarString(number=3, value=33), GuitarString(number=4, value=28)]
# Lars
# 5
# [GuitarString(number=1, value=0), GuitarString(number=2, value=0), GuitarString(number=3, value=0), GuitarString(number=4, value=0), GuitarString(number=5, value=0), GuitarString(number=6, value=0)]
# 64

# %%
print(guitarpro.BeatStatus.empty)
for measure in vocals.measures:
    for voice in measure.voices:
        for beat in voice.beats:
            #print(beat.status)
            #print(guitarpro.BeatStatus.empty)
            if beat.status == guitarpro.BeatStatus.rest:
                #print(beat.status)
                continue
            notes = [beat.duration.value]
            for note in beat.notes:
                print(note.type)
                notes.append((note.value, note.string))
            print(notes)
# Out:
# BeatStatus.empty
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [8, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [4, (4, 4)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [1, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [1, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (3, 5), (1, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [4, (4, 4)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [1, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [1, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [2, (0, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [4, (4, 4)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [1, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [1, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (4, 4)]
# NoteType.normal
# [8, (2, 3)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# [4, (2, 5)]
# NoteType.normal
# [4, (4, 4)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [1, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [2, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.tie
# NoteType.tie
# [4, (0, 5), (0, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [1, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [4, (4, 5), (2, 6)]
# NoteType.normal
# [8, (4, 5)]
# NoteType.normal
# [8, (3, 5)]
# NoteType.normal
# NoteType.normal
# [4, (4, 4), (2, 5)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [1, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [2, (0, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.tie
# NoteType.tie
# [8, (0, 5), (0, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (5, 5), (3, 6)]
# NoteType.normal
# NoteType.normal
# [8, (4, 5), (2, 6)]
# NoteType.normal
# NoteType.normal
# [8, (2, 5), (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [8, (0, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (5, 4)]
# NoteType.normal
# [8, (6, 6)]
# NoteType.normal
# [4, (5, 6)]
# NoteType.normal
# [8, (7, 5)]
# NoteType.normal
# [8, (0, 6)]
# NoteType.tie
# [1, (0, 6)]

# %%
print(preprocess.fileconvert(file))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(preprocess.fileconvert(file))
#
# NameError: name 'preprocess' is not defined
